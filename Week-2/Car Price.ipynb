# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('CarPrice_Assignment.xlsx')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isna().isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
print('Unique elements in Car_Name are',df['CarName'].nunique())
# Out:
# Unique elements in Car_Name are 147

# %%
car_counts=df['CarName'].value_counts()
car_counts
# Out:
# peugeot 504             6
# toyota corolla          6
# toyota corona           6
# subaru dl               4
# mitsubishi outlander    3
#                        ..
# alfa-romero giulia      1
# audi 100 ls             1
# chevrolet vega 2300     1
# honda civic (auto)      1
# dodge coronet custom    1
# Name: CarName, Length: 147, dtype: int64

# %% [markdown]
# ## Calculating correlation matrix

# %%
corr_matrix = df.corr()

plt.figure(figsize=(10, 8))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)

for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        text = f"{corr_matrix.iloc[i, j]:.2f}"
        plt.text(j, i, text, ha='center', va='center', color='black')

plt.title('Correlation Matrix with Values')
plt.show()

# %% [markdown]
# ## Distribution of Car Prices

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['price'], bins=20)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Car Prices')
plt.show()

# %% [markdown]
# ## Count of each cars

# %%
plt.figure(figsize=(12, 6))
car_counts[car_counts>1].plot(kind='bar')
plt.xlabel('Car Name')
plt.ylabel('Count')
plt.title('Count of Cars')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Categorical variables analysis
#
# ### Calculating frequency of fueltype, aspiration, carbody and drivewheel

# %%
categorical_cols = ['fueltype', 'aspiration', 'carbody', 'drivewheel']
for col in categorical_cols:
   
    category_counts = df[col].value_counts()
    
    plt.figure(figsize=(8, 6))
    category_counts.plot(kind='bar')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.title('Frequency of Categories: ' + col)
    plt.show()

# %% [markdown]
# ## Distribution of car prices for each Car body type

# %%
avg_price_by_body = df.groupby('carbody')['price'].mean().reset_index()
avg_price_by_body = avg_price_by_body.sort_values('price')
plt.figure(figsize=(8, 6))
plt.bar(avg_price_by_body['carbody'], avg_price_by_body['price'])
plt.xlabel('Car Body Type')
plt.ylabel('Average Price')
plt.title('Average Car Price by Body Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Analyze the correlation between car price and mileage

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['citympg'], df['price'])
plt.xlabel('City MPG')
plt.ylabel('Price')
plt.title('Car Price vs City MPG')
plt.show()

# %% [markdown]
# ## Relationship between the car price and the horsepower of the car

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['horsepower'], df['price'])
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Car Price vs Horsepower')
plt.show()

# %% [markdown]
# ## Relationships between car price and specific features like the compression ratio, boreratio, or stroke

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.scatter(df['compressionratio'], df['price'])
plt.xlabel('Compression Ratio')
plt.ylabel('Price')
plt.title('Car Price vs Compression Ratio')

plt.subplot(1, 3, 2)
plt.scatter(df['boreratio'], df['price'])
plt.xlabel('Bore Ratio')
plt.ylabel('Price')
plt.title('Car Price vs Bore Ratio')

plt.subplot(1, 3, 3)
plt.scatter(df['stroke'], df['price'])
plt.xlabel('Stroke')
plt.ylabel('Price')
plt.title('Car Price vs Stroke')

plt.tight_layout()
plt.show()
